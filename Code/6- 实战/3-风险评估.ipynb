# %%
# 基本信息
import numpy as np
import pandas as pd

# 股票数据读取
import pandas_datareader as pdr

# 可视化
import matplotlib.pyplot as plt
import seaborn as sns

# time
from datetime import datetime

# %%
start = datetime(2015,9,20)
company = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'FB']
top_tech_df = pdr.get_data_yahoo(company, start=start)['Adj Close']

# %%
top_tech_df.head()
# Out:
# Symbols           AAPL        AMZN         FB        GOOG       MSFT
# Date
# 2015-09-21  108.812408  548.390015  95.550003  635.440002  41.003284
# 2015-09-22  107.102913  538.400024  92.959999  622.690002  40.808079
# 2015-09-23  107.971840  536.070007  93.970001  622.359985  40.780182
# 2015-09-24  108.614059  533.750000  94.410004  625.799988  40.817371
# 2015-09-25  108.340164  524.250000  92.769997  611.969971  40.845257

# %%
pct_change_df = top_tech_df.pct_change()

# %%
top_tech_df.plot()

# %%
top_tech_df[['AAPL', 'FB', 'MSFT']].plot()

# %%
sns.jointplot('AMZN', 'GOOG', top_tech_df, kind='scatter')

# %%
sns.pairplot(top_tech_df)

# %%
top_tech_df.quantile()
