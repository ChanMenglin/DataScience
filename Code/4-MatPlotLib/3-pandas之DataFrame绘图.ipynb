# %% [markdown]
# # pandas 之 DataFrame 绘图

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(
    np.random.randint(1, 10, 40).reshape(10, 4),
    columns=['A', 'B', 'C', 'D']
)

# %%
df.plot()

# %%
# 按行（index）画图
df.iloc[5].plot()

# %%
for i in df.index:
    df.iloc[i].plot(label=str(i))
plt.legend()
plt.show()

# %%
# 按列（columns）画图
for i in df.columns:
    df[i].plot(label=str(i))
plt.legend()
plt.show()

# %%
df.T.plot()
