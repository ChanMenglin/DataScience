# %% [markdown]
# # MatPlotLib-密度图

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s = pd.Series(np.random.randn(1000))

# %%
# 线性图
s.plot()

# %%
# 密度图
s.plot(kind='kde')
